# %%
class Person():
    def__init__(self, name, age, hobby):
        self.hello='안녕하세요' #인스턴스 변
        self.name=Name
        self.age=age
        self.hobby=hobby

    def hi(self):
        print(self.hello)
jin = person('지민','35','운동')
jin.hi()
# Out:
# hello world
# 20
# 30
